# %%
import Quandl
import pandas as pd
import numpy as np
import blaze as bz

# %%
# %matplotlib inline

# %%
with open('../quandl_api_key.txt', 'r') as f:
    api_key = f.read()

# %%
db = Quandl.get("EOD/DB", authtoken=api_key)

# %%
db.tail()
# Out:
#              Open     High    Low  Close   Volume  Dividend  Split  Adj_Open  \
# Date
# 2015-05-04  32.09  32.2400  32.05  32.09   991327         0      1     32.09
# 2015-05-05  31.94  32.0000  31.50  31.51  1793356         0      1     31.94
# 2015-05-06  32.06  32.4501  31.85  32.26  2305069         0      1     32.06
# 2015-05-07  32.13  32.2400  31.92  32.05  1344966         0      1     32.13
# 2015-05-08  31.85  32.5000  31.82  32.42  1271251         0      1     31.85
#
#             Adj_High  Adj_Low  Adj_Close  Adj_Volume
# Date
# 2015-05-04   32.2400    32.05      32.09      991327
# 2015-05-05   32.0000    31.50      31.51     1793356
# 2015-05-06   32.4501    31.85      32.26     2305069
# 2015-05-07   32.2400    31.92      32.05     1344966
# 2015-05-08   32.5000    31.82      32.42     1271251

# %%
bz.odo(db, 'hdfstore://stocks.hdf5::/db')
# Out:
# frame_table  (typ->appendable,nrows->4648,ncols->12,indexers->[index])

# %%
db2 = bz.odo('hdfstore://stocks.hdf5::/db', pd.DataFrame)

# %%
db2 = bz.Data('hdfstore://stocks.hdf5::')

# %%
db
# Out:
#              Open     High      Low  Close   Volume  Dividend  Split  \
# Date
# 1996-11-18  47.50  48.0000  46.2500  47.50     1700         0      1
# 1996-11-19  47.87  48.1200  47.2500  47.87     6300         0      1
# 1996-11-20  47.50  48.1200  47.5000  47.50    23800         0      1
# 1996-11-21  48.00  48.0000  47.5000  48.00     4600         0      1
# 1996-11-22  47.37  47.8700  47.3700  47.37      700         0      1
# 1996-11-25  47.50  47.8700  47.0000  47.50     4700         0      1
# 1996-11-26  47.75  47.7500  46.7500  47.75     4500         0      1
# 1996-11-27  46.75  47.6200  46.7500  46.75     1800         0      1
# 1996-11-29  47.62  48.0000  47.5000  47.62     4300         0      1
# 1996-12-02  47.00  47.5000  46.8700  47.00    23600         0      1
# 1996-12-03  46.62  47.0000  46.0000  46.62    32000         0      1
# 1996-12-04  46.62  46.8700  46.2500  46.62    19300         0      1
# ...

# %%
import bcolz

# %%
bz.odo(db.reset_index(), 'db2.bcolz')
# Out:
# ctable((4648,), [('Date', '<M8[us]'), ('Open', '<f8'), ('High', '<f8'), ('Low', '<f8'), ('Close', '<f8'), ('Volume', '<f8'), ('Dividend', '<f8'), ('Split', '<f8'), ('Adj_Open', '<f8'), ('Adj_High', '<f8'), ('Adj_Low', '<f8'), ('Adj_Close', '<f8'), ('Adj_Volume', '<f8')])
#   nbytes: 472.06 KB; cbytes: 1.62 MB; ratio: 0.28
#   cparams := cparams(clevel=5, shuffle=True, cname='blosclz')
#   rootdir := 'db2.bcolz'
# [ (datetime.datetime(1996, 11, 18, 0, 0), 47.5, 48.0, 46.25, 47.5, 1700.0, 0.0, 1.0, 36.14000000000001, 36.520421052631576, 35.18894736842105, 36.14000000000001, 1700.0)
#  (datetime.datetime(1996, 11, 19, 0, 0), 47.87, 48.12, 47.25, 47.87, 6300.0, 0.0, 1.0, 36.41999999999997, 36.61020263212866, 35.94829747232085, 36.41999999999997, 6300.0)
#  (datetime.datetime(1996, 11, 20, 0, 0), 47.5, 48.12, 47.5, 47.5, 23800.0, 0.0, 1.0, 36.14000000000001, 36.611722105263155, 36.14000000000001, 36.14000000000001, 23800.0)
#  ...,
# ...

# %%
db3 = bz.odo('db2.bcolz', pd.DataFrame)

# %%
db3 = bz.Data('db2.bcolz')

# %%
pd.ewma(bz.odo(db3.Close, pd.TimeSeries), com=15).plot()

# %%
bz.odo(db3[['Date', 'Close']], pd.DataFrame).set_index('Date').pct_change().plot()

# %%
s = bz.odo(db3[['Date', 'Close']], pd.DataFrame).set_index('Date')

# %%
# !cd ..
from stock2 import StockModel
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-76-d887be4e6006> in <module>()
#       1 get_ipython().system('cd ..')
# ----> 2 from stock2 import StockModel
#
# ImportError: No module named 'stock2'

# %%
cd ..
# Out:
# /Users/miguel/Jottacloud/devel/osqf2015

# %%
# %reload_ext autoreload
# %autoreload 3

# %%
from stock2 import StockModel

# %%
# %clear StockModel

# %%
s = StockModel()

# %%
s.source.dataspecs()
# Out:
# set()
